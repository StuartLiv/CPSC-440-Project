# %% [markdown]
# # 256x256 Extractor
#
# The following code takes various color images from different online dataset sources (one folder with nested folders of different images inside), combines them, renames them uniformly, and resizes anything that's big enough to 256x256 resolution. I'm using offline directories (on my local machine) outside of this repo because Github causes issues if I make more than 10000 changes at once.
#
# Further dataset processing will occur in `image-preprocess_256.ipynb`

# %%
import glob
import shutil
import os
from PIL import Image
import random

# Source directory with subfolders
raw_images_source = "C:/Users/ziven/OneDrive/School/UBC/Fourth Year/CPSC 440/Final Project/Offline/random_images"

color_raw_dir = "C:/Users/ziven/OneDrive/School/UBC/Fourth Year/CPSC 440/Final Project/Offline/extracted_256s"

color_dir = "C:/Users/ziven/OneDrive/School/UBC/Fourth Year/CPSC 440/Final Project/Offline/extracted_downsized_256s"

# %% [markdown]
# The following code block extracts images from a sub-directory structure (as they are in the aerial images dataset) and places them uniformly in one directory with unique numbers 1 thru whatever max is necessary.

# %%
# Get a list of all image files in nested folders
files = glob.glob(raw_images_source + '/**/*.jpeg', recursive=True)

# Randomly shuffle the images, so we can partition them into training and testing based on number alone
random.shuffle(files)

counter = 1

# Copy each image to the destination folder
for file in files:
    filename = os.path.basename(file)
    new_filename = f"{counter}.jpg"
    destination_path = os.path.join(color_raw_dir, new_filename)

    # Ensure unique filenames
    while os.path.exists(destination_path):
        counter += 1
        new_filename = f"{counter}.jpg"
        destination_path = os.path.join(color_raw_dir, new_filename)

    # Open the image to check its aspect ratio
    img = Image.open(file)
    width, height = img.size

    # Check if the aspect ratio is square
    if height >= 256 and width >= 256:
        # Copy the image to the destination folder
        shutil.copy(file, destination_path)
        # Increment the counter
        counter += 1
    else:
        print(f"Discarded {filename} because it is not square or has a dimension that is too small.")
        continue

print("All files copied with unique names. Total number extracted:", counter)
# Out:
# Discarded Glacier-Train (1971).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (885).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (786).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (552).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1130).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (3205).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain-Valid (211).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (634).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (164).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Test (130).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (3805).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (4).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Test (86).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1540).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier (320).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Test (101).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1302).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1718).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1616).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Valid (149).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (297).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1612).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (603).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain-Test (11).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4177).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1678).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Valid (193).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1321).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1040).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Test (162).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain-Valid (298).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1842).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4909).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1291).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (616).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (117).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4506).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Valid (185).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1599).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Valid (158).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1586).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (994).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1587).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Valid (236).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain-Test (56).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1540).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (3887).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1365).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1477).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (700).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (861).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain-Test (45).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1621).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4449).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (2970).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Valid (289).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1017).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Valid (129).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Valid (44).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1957).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1543).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Valid (179).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (3300).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4544).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (156).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4527).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (90).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1599).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1377).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (346).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Test (141).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (970).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (3).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1841).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1679).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (345).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (3250).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1832).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (863).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Valid (87).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (735).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (246).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (596).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1589).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1232).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (100).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (176).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1114).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Valid (121).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1409).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (52).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Valid (259).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1160).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1270).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (107).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (470).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (316).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1495).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (790).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (3344).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (3456).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1711).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1070).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Valid (119).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (900).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (266).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1828).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (704).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (946).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Valid (288).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (3636).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (953).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (314).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1584).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4368).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1474).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1125).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train
jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1044).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4066).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (278).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1503).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (3489).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (2980).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Valid (103).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1811).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1058).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1095).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1749).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1414).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1650).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (430).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (928).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4180).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1662).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (266).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (839).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4510).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4089).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1722).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (705).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (372).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (436).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1274).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (202).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1966).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (225).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1761).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (385).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (525).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1047).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1257).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (563).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4608).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (272).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1194).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (672).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1658).jpeg because it is not square or has a dimension that is too small.
# ...
# Discarded Forest-Train (1430).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4142).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Valid (186).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier (373).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1563).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Valid (139).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (259).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1666).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (227).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1812).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (419).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (899).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (3671).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1634).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1396).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1169).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (228).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1173).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (871).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4521).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (3218).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (791).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain-Test (20).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (366).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1606).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1973).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (452).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1343).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (607).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (698).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4403).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (592).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1136).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Valid (281).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1960).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1421).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Valid (135).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Valid (145).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (3884).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1318).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1356).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4757).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (305).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (3914).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (997).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (374).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (306).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Valid (30).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4471).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1170).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1347).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Valid (31).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain-Valid (225).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (3019).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (792).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1209).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (516).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4110).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1595).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (96).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1465).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1463).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1467).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier (315).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (114).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1870).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (817).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1154).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Valid (293).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1993).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1063).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4600).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (639).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Valid (300).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1118).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4706).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (760).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1161).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (526).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4149).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (817).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1909).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Valid (11).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1771).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1505).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1369).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (57).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1834).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (713).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1744).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (842).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1059).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1087).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (687).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (314).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1494).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (3408).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1260).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (372).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1279).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1169).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain-Valid (124).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier (338).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (575).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1587).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (609).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1709).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1797).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (755).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1326).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1127).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1994).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (997).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1794).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1828).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain-Valid (214).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier (378).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Test (27).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4577).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1573).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain-Valid (66).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1297).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (591).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (980).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1409).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (572).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (614).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1126).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1409).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1972).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1288).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1139).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (82).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4512).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4202).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (35).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (182).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (211).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Valid (124).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Valid (46).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Test (125).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Valid (15).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (227).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1413).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (460).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1394).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Valid (204).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Test (158).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4025).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1899).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (1455).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (695).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (960).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (3020).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Valid (138).jpeg because it is not square or has a dimension that is too small.
# Discarded Mountain (4847).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Train (38).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Train (1024).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (613).jpeg because it is not square or has a dimension that is too small.
# Discarded Forest-Train (1971).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Valid (265).jpeg because it is not square or has a dimension that is too small.
# Discarded Desert-Valid (198).jpeg because it is not square or has a dimension that is too small.
# Discarded Glacier-Valid (101).jpeg because it is not square or has a dimension that is too small.
# Discarded Coast-Train (1265).jpeg because it is not square or has a dimension that is too small.
# All files copied with unique names. Total number extracted: 1

# %%
target_size = (256, 256)

# Iterate through all files in the source directory
for filename in os.listdir(color_raw_dir):
    if filename.lower().endswith(".jpg"):
        try:
            # Open the image
            img_path = os.path.join(color_raw_dir, filename)
            img = Image.open(img_path)

            # Resize the image while preserving aspect ratio
            img.thumbnail(target_size, Image.ANTIALIAS)

            # Save the resized image to the destination folder
            new_filename = os.path.splitext(filename)[0] + ".jpg"
            img.save(os.path.join(color_dir, new_filename), "JPEG")

            # print(f"Resized {filename} to {target_size[0]}x{target_size[1]}")
        except Exception as e:
            print(f"Error processing {filename}: {e}")

print("All images resized")
